# %%
import numpy as np
import random
from scipy import stats
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
import numpy as np
import pandas as pd
import random
from scipy import stats

# Generate data
rvs = []
params = []
for i in range(5):
    u = random.randint(0, 5)
    sigma = random.randint(1, 3)
    params.append((u, sigma))
    rvs.append(stats.norm(loc=u, scale=sigma).rvs(10))

# %%
rvs = np.array(rvs)

df = pd.DataFrame({
    'x': x,
    'y': y[0],
    **{f'rvs_{i+1}': rvs[i] for i in range(5)}
})

# Saving the DataFrame to an Excel file
output_path = "/home/abhishek/Documents/workspace/Sem-5/Probabilty_Random_Processs/Co-relation/organized_data.xlx"
df.to_excel(output_path, index=False)

output_path
# Out:
# '/home/abhishek/Documents/workspace/Sem-5/Probabilty_Random_Processs/Co-relation/organized_data.xlsx'

# %%
plt.plot(x)
plt.show()

# %%
plt.hist(x)
plt.hist(y)
# Out:
# (array([ 4.,  4.,  9., 15., 17., 19.,  9., 14.,  5.,  4.]),
#  array([0.21445525, 1.09409718, 1.97373912, 2.85338106, 3.733023  ,
#         4.61266493, 5.49230687, 6.37194881, 7.25159074, 8.13123268,
#         9.01087462]),
#  <BarContainer object of 10 artists>)

# %%
sns.kdeplot(x)
sns.kdeplot(y)
plt.show()

# %%
plt.scatter(x,y)

# %%
plt.scatter(x,z)

# %%
plt.scatter(z,y)

# %%
# Out:
# Excel file created successfully!
